# %%
import json

def is_json(myjson):
    try:
        json_object = json.loads(myjson)
    except ValueError as e:
        return False
    return True

with open('dataset/2023-01-25/travellife.json', 'r') as file:
    line = file.readline()  # read only the first line/object
    print(f"Is the first line valid JSON?: {is_json(line)}")
# Out:
# Is the first line valid JSON?: True

# %%
import json

# Open the file and load it as JSON
with open('dataset/2023-01-25/digitalnomadgirl.json', 'r') as f:
    data = json.load(f)

first_object = data[0]
print(json.dumps(first_object, indent=4))
# Out:
# {
#     "$other": {
#         "videoLinkHeaders": {
#             "Cookie": "tt_chain_token=MSCG3YRE/iXZSI6vfKELrg==;",
#             "Origin": "https://www.tiktok.com",
#             "Referer": "https://www.tiktok.com/"
#         }
#     },
#     "cursor": "30",
#     "extra": {
#         "fatal_item_ids": [],
#         "logid": "20230127103609FAA5676C515BBC3500D8",
#         "now": 1674815769000
#     },
#     "hasMore": true,
#     "itemList": [
#         {
#             "BAInfo": "",
#             "adAuthorization": false,
#             "adLabelVersion": 0,
#             "author": {
#                 "avatarLarger": "https://p19-sign.tiktokcdn-us.com/tos-useast5-avt-0068-tx/b606b96e63e4ff2d345e9b9fed321446~c5_1080x1080.jpeg?x-expires=1674986400&x-signature=wuRKUThw0x1GCJZRYgy55MtimBE%3D",
# ...
